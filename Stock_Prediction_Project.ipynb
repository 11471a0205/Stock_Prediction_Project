# %% [markdown]
# <a href="https://colab.research.google.com/github/11471a0205/Stock_Prediction_Project/blob/main/Stock_Prediction_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as apprcepd_pdsn
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
apprcepdta = apprcepd_pdsn.read_csv('/content/drive/MyDrive/Datasets/HistoricalData_1720352415029.csv')

# %%
apprcepdta
# Out:
#             Date Close/Last     Volume      Open      High       Low
# 0     07/05/2024    $226.34   60412410   $221.65   $226.45   $221.65
# 1     07/03/2024    $221.55   37369800   $220.00   $221.55   $219.03
# 2     07/02/2024    $220.27   58046180   $216.15   $220.38   $215.10
# 3     07/01/2024    $216.75   60402930   $212.09   $217.51   $211.92
# 4     06/28/2024    $210.62   82542720   $215.77   $216.07   $210.30
# ...          ...        ...        ...       ...       ...       ...
# 2512  07/11/2014    $23.805  135841200    $23.84  $23.9725  $23.7156
# 2513  07/10/2014   $23.7587  158535200    $23.44  $23.8875    $23.38
# 2514  07/09/2014   $23.8475  145069400    $23.86  $23.9875    $23.69
# 2515  07/08/2014   $23.8375  260447840  $24.0675    $24.20    $23.48
# 2516  07/07/2014    $23.992  219236120   $23.535  $23.9975   $23.525
#
# [2517 rows x 6 columns]

# %%
apprcepdta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2517 non-null   object
#  1   Close/Last  2517 non-null   object
#  2   Volume      2517 non-null   int64
#  3   Open        2517 non-null   object
#  4   High        2517 non-null   object
#  5   Low         2517 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 118.1+ KB

# %%
apprcepdta.describe()
# Out:
#              Volume
# count  2.517000e+03
# mean   1.248808e+08
# std    7.152452e+07
# min    2.404834e+07
# 25%    7.626704e+07
# 50%    1.055755e+08
# 75%    1.530332e+08
# max    7.576780e+08

# %%
apprcepdta.isnull().sum()
# Out:
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# dtype: int64

# %%
apprcep_duptes = apprcepdta[apprcepdta.duplicated(keep=False)]

print("Duplicate rows in the DataFrame:", len(apprcep_duptes))
# Out:
# Duplicate rows in the DataFrame: 0

# %% [markdown]
# **Convert 'Date' column to datetime format**

# %%
apprcepdta['Date'] = apprcepd_pdsn.to_datetime(apprcepdta['Date'])

# %%
apprcepdta
# Out:
#            Date Close/Last     Volume      Open      High       Low
# 0    2024-07-05    $226.34   60412410   $221.65   $226.45   $221.65
# 1    2024-07-03    $221.55   37369800   $220.00   $221.55   $219.03
# 2    2024-07-02    $220.27   58046180   $216.15   $220.38   $215.10
# 3    2024-07-01    $216.75   60402930   $212.09   $217.51   $211.92
# 4    2024-06-28    $210.62   82542720   $215.77   $216.07   $210.30
# ...         ...        ...        ...       ...       ...       ...
# 2512 2014-07-11    $23.805  135841200    $23.84  $23.9725  $23.7156
# 2513 2014-07-10   $23.7587  158535200    $23.44  $23.8875    $23.38
# 2514 2014-07-09   $23.8475  145069400    $23.86  $23.9875    $23.69
# 2515 2014-07-08   $23.8375  260447840  $24.0675    $24.20    $23.48
# 2516 2014-07-07    $23.992  219236120   $23.535  $23.9975   $23.525
#
# [2517 rows x 6 columns]

# %%
apprcepdta['Close/Last'] = apprcepdta['Close/Last'].str.replace('$', '', regex=False).astype(float)
apprcepdta['Open'] = apprcepdta['Open'].str.replace('$', '', regex=False).astype(float)
apprcepdta['High'] = apprcepdta['High'].str.replace('$', '', regex=False).astype(float)
apprcepdta['Low'] = apprcepdta['Low'].str.replace('$', '', regex=False).astype(float)

# %%
apprcepdta
# Out:
#            Date  Close/Last     Volume      Open      High       Low
# 0    2024-07-05    226.3400   60412410  221.6500  226.4500  221.6500
# 1    2024-07-03    221.5500   37369800  220.0000  221.5500  219.0300
# 2    2024-07-02    220.2700   58046180  216.1500  220.3800  215.1000
# 3    2024-07-01    216.7500   60402930  212.0900  217.5100  211.9200
# 4    2024-06-28    210.6200   82542720  215.7700  216.0700  210.3000
# ...         ...         ...        ...       ...       ...       ...
# 2512 2014-07-11     23.8050  135841200   23.8400   23.9725   23.7156
# 2513 2014-07-10     23.7587  158535200   23.4400   23.8875   23.3800
# 2514 2014-07-09     23.8475  145069400   23.8600   23.9875   23.6900
# 2515 2014-07-08     23.8375  260447840   24.0675   24.2000   23.4800
# 2516 2014-07-07     23.9920  219236120   23.5350   23.9975   23.5250
#
# [2517 rows x 6 columns]

# %%
apprcepdta.describe()
# Out:
#                                 Date   Close/Last        Volume         Open  \
# count                           2517  2517.000000  2.517000e+03  2517.000000
# mean   2019-07-04 01:17:14.088200448    86.294156  1.248808e+08    86.223210
# min              2014-07-07 00:00:00    22.585000  2.404834e+07    22.500000
# 25%              2017-01-03 00:00:00    32.373800  7.626704e+07    32.375000
# 50%              2019-07-05 00:00:00    54.005000  1.055755e+08    54.150000
# 75%              2021-12-31 00:00:00   145.910000  1.530332e+08   145.660000
# max              2024-07-05 00:00:00   226.340000  7.576780e+08   221.650000
# std                              NaN    59.322795  7.152452e+07    59.263133
#
#              High          Low
# count  2517.00000  2517.000000
# mean     87.15339    85.357920
# min      22.91750    22.367500
# 25%      32.64250    32.082500
# 50%      54.87500    53.460000
# 75%     147.36010   144.180000
# max     226.45000   221.650000
# ...

# %%
apprcepdta.columns
# Out:
# Index(['Date', 'Close/Last', 'Volume', 'Open', 'High', 'Low'], dtype='object')

# %% [markdown]
# **Plotting the Closing Price:**

# %%
import matplotlib.pyplot as apprcep_mplit

# %%
apprcep_mplit.style.use('seaborn-v0_8-dark-palette')
apprcep_mplit.figure(figsize=(14, 7))

apprcep_mplit.figure(figsize=(14, 7))
apprcep_mplit.plot(apprcepdta['Close/Last'], label='Closing Price')
apprcep_mplit.title('Apple stocks Over Time')
apprcep_mplit.xlabel('Date')
apprcep_mplit.ylabel('Closing Price')
apprcep_mplit.legend()
apprcep_mplit.show()

# %% [markdown]
# **Seasonal Decomposition**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose as apprcep_sadcmp

# %%
apprcep_dcmptn = apprcep_sadcmp(apprcepdta['Close/Last'], model='multiplicative', period=365)
apprcep_dcmptn.plot()
apprcep_mplit.show()

# %%
apprcepdta = apprcepdta[['Date','Close/Last']]

# %%
apprcepdta
# Out:
#            Date  Close/Last
# 0    2024-07-05    226.3400
# 1    2024-07-03    221.5500
# 2    2024-07-02    220.2700
# 3    2024-07-01    216.7500
# 4    2024-06-28    210.6200
# ...         ...         ...
# 2512 2014-07-11     23.8050
# 2513 2014-07-10     23.7587
# 2514 2014-07-09     23.8475
# 2515 2014-07-08     23.8375
# 2516 2014-07-07     23.9920
#
# [2517 rows x 2 columns]

# %%
apprcepdta.shape
# Out:
# (2517, 2)

# %%
apprcepdta.to_csv("/content/drive/MyDrive/Datasets/preprocessed_apple_stocks.csv", index = False)
